# %%
def add_ten(x):
    return x + 10

# %%
script = """
def add_ten(x):
    return x + 10
"""

# %%
script
# Out:
# '\ndef add_ten(x):\n    return x + 10\n'

# %%
filename = "./src_day3/add_ten.py"

# %%
with open(filename, 'w') as file:
    file.write(script)
